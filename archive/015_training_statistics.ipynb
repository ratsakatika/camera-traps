    'Overall Recall': [0.9117, 0.9147, 0.9210, 0.9294, 0.9294, 0.9335, 0.9384, 0.9406, 0.9409, 0.9368, 0.9349, 0.9428, 0.9433, 0.9439, 0.9433, 0.9458, 0.9433, 0.9384, 0.9463, 0.9469, 0.9261, 0.9384, 0.9419, 0.9449, 0.9452, 0.9463, 0.9458, 0.9477, 0.9458, 0.9449, 0.9444],
    'Wild Boar Precision': [0.9792, 0.8079, 0.9071, 0.8789, 0.9213, 0.9322, 0.9401, 0.9605, 0.9402, 0.9240, 0.9523, 0.9430, 0.9482, 0.9533, 0.9392, 0.9532, 0.9598, 0.9649, 0.9519, 0.9533, 0.8111, 0.9429, 0.9610, 0.9519, 0.9532, 0.9558, 0.9531, 0.9558, 0.9557, 0.9466, 0.9531],
    'Wild Boar Recall': [0.9360, 0.9929, 0.9858, 0.9915, 0.9829, 0.9772, 0.9829, 0.9673, 0.9844, 0.9858, 0.9659, 0.9886, 0.9886, 0.9872, 0.9886, 0.9858, 0.9858, 0.9787, 0.9844, 0.9872, 0.9957, 0.9872, 0.9801, 0.9858, 0.9844, 0.9844, 0.9829, 0.9844, 0.9829, 0.9829, 0.9829],
    'Bear Precision': [0.9620, 0.9148, 0.8228, 0.9133, 0.8408, 0.8744, 0.9140, 0.8883, 0.9421, 0.9108, 0.8424, 0.9437, 0.9438, 0.9413, 0.9440, 0.9547, 0.9548, 0.9339, 0.9443, 0.9548, 0.9817, 0.9544, 0.9235, 0.9438, 0.9358, 0.9335, 0.9311, 0.9460, 0.9359, 0.9382, 0.9359],
    'Bear Recall': [0.9347, 0.9460, 0.9631, 0.9574, 0.9602, 0.9688, 0.9659, 0.9716, 0.9716, 0.9574, 0.9716, 0.9517, 0.9545, 0.9574, 0.9574, 0.9574, 0.9602, 0.9631, 0.9631, 0.9602, 0.9148, 0.9517, 0.9602, 0.9545, 0.9517, 0.9602, 0.9602, 0.9460, 0.9545, 0.9489, 0.9545],
    'Wild Boar & Bear Recall Harmonic Mean': [0.9353, 0.9689, 0.9743, 0.9741, 0.9714, 0.9730, 0.9743, 0.9694, 0.9779, 0.9714, 0.9687, 0.9698, 0.9713, 0.9721, 0.9728, 0.9714, 0.9728, 0.9708, 0.9736, 0.9735, 0.9535, 0.9691, 0.9701, 0.9699, 0.9678, 0.9707, 0.9714, 0.9648, 0.9685, 0.9656, 0.9685]
}

df_new = pd.DataFrame(data_new)

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(3, 2, figsize=(15, 18))

# Plot Training and Validation Loss for initial dataset
axes[0, 0].plot(df['Epoch'], df['Train Loss'], label='Train Loss', marker='o')
axes[0, 0].plot(df['Epoch'], df['Validation Loss'], label='Validation Loss', marker='o')
axes[0, 0].axvline(x=26, color='red', linestyle='--', label='Best Epoch')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].set_title('Training and Validation Loss (Initial Dataset)')
axes[0, 0].legend()
axes[0, 0].grid(True)

# Plot Recall for Overall, Wild Boar, Bear, and Harmonic Mean for initial dataset
axes[1, 0].plot(df['Epoch'], df['Overall Recall'], label='Overall Recall', marker='o')
axes[1, 0].plot(df['Epoch'], df['Wild Boar Recall'], label='Wild Boar Recall', marker='o')
axes[1, 0].plot(df['Epoch'], df['Bear Recall'], label='Bear Recall', marker='o')
axes[1, 0].plot(df['Epoch'], df['Wild Boar & Bear Recall Harmonic Mean'], label='Harmonic Mean Recall', marker='o')
axes[1, 0].axvline(x=26, color='red', linestyle='--', label='Best Epoch')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Recall')
axes[1, 0].set_title('Recall (Initial Dataset)')
axes[1, 0].legend()
axes[1, 0].grid(True)

# Plot Precision for Overall, Wild Boar, and Bear for initial dataset
axes[2, 0].plot(df['Epoch'], df['Overall Precision'], label='Overall Precision', marker='o')
axes[2, 0].plot(df['Epoch'], df['Wild Boar Precision'], label='Wild Boar Precision', marker='o')
axes[2, 0].plot(df['Epoch'], df['Bear Precision'], label='Bear Precision', marker='o')
axes[2, 0].axvline(x=26, color='red', linestyle='--', label='Best Epoch')
axes[2, 0].set_xlabel('Epoch')
axes[2, 0].set_ylabel('Precision')
axes[2, 0].set_title('Precision (Initial Dataset)')
axes[2, 0].legend()
axes[2, 0].grid(True)

# Plot Training and Validation Loss for new dataset
axes[0, 1].plot(df_new['Epoch'], df_new['Train Loss'], label='Train Loss', marker='o')
axes[0, 1].plot(df_new['Epoch'], df_new['Validation Loss'], label='Validation Loss', marker='o')
axes[0, 1].axvline(x=8, color='red', linestyle='--', label='Best Epoch')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Loss')
axes[0, 1].set_title('Training and Validation Loss (New Dataset)')
axes[0, 1].legend()
axes[0, 1].grid(True)

# Plot Recall for Overall, Wild Boar, Bear, and Harmonic Mean for new dataset
axes[1, 1].plot(df_new['Epoch'], df_new['Overall Recall'], label='Overall Recall', marker='o')
axes[1, 1].plot(df_new['Epoch'], df_new['Wild Boar Recall'], label='Wild Boar Recall', marker='o')
axes[1, 1].plot(df_new['Epoch'], df_new['Bear Recall'], label='Bear Recall', marker='o')
axes[1, 1].plot(df_new['Epoch'], df_new['Wild Boar & Bear Recall Harmonic Mean'], label='Harmonic Mean Recall', marker='o')
axes[1, 1].axvline(x=8, color='red', linestyle='--', label='Best Epoch')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('Recall')
axes[1, 1].set_title('Recall (New Dataset)')
axes[1, 1].legend()
axes[1, 1].grid(True)

# Plot Precision for Overall, Wild Boar, and Bear for new dataset
axes[2, 1].plot(df_new['Epoch'], df_new['Overall Precision'], label='Overall Precision', marker='o')
axes[2, 1].plot(df_new['Epoch'], df_new['Wild Boar Precision'], label='Wild Boar Precision', marker='o')
axes[2, 1].plot(df_new['Epoch'], df_new['Bear Precision'], label='Bear Precision', marker='o')
axes[2, 1].axvline(x=8, color='red', linestyle='--', label='Best Epoch')
axes[2, 1].set_xlabel('Epoch')
axes[2, 1].set_ylabel('Precision')
axes[2, 1].set_title('Precision (New Dataset)')
axes[2, 1].legend()
axes[2, 1].grid(True)


plt.tight_layout()
plt.show()
