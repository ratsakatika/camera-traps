# %%
from ultralytics import settings

# View all settings
print(settings)
# Out:
# {'settings_version': '0.0.4', 'datasets_dir': '/home/tom-ratsakatika/VSCode/camera-traps/datasets', 'weights_dir': 'weights', 'runs_dir': 'runs', 'uuid': 'caac3e504e111a4659f6a3dd5f3bbf05e178441fff904e37cc355434eebd143d', 'sync': True, 'api_key': '', 'openai_api_key': '', 'clearml': True, 'comet': True, 'dvc': True, 'hub': True, 'mlflow': True, 'neptune': True, 'raytune': True, 'tensorboard': True, 'wandb': True}

# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
model = YOLO('yolov8n.yaml')

# %%
# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8n.pt')

# %%
# Train the model using the 'coco128.yaml' dataset for 3 epochs
results = model.train(data='coco128.yaml', epochs=3)
# Out:
# New https://pypi.org/project/ultralytics/8.1.41 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.40 🚀 Python-3.12.2 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3904MiB)
# ...

# %%
# Evaluate the model's performance on the validation set
results = model.val()
# Out:
# Ultralytics YOLOv8.1.40 🚀 Python-3.12.2 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3904MiB)
# Model summary (fused): 168 layers, 3151904 parameters, 0 gradients
# val: Scanning /home/tom-ratsakatika/VSCode/camera-traps/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100%|██████████| 128/128 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.81it/s]
#                    all        128        929      0.654      0.544      0.628      0.467
#                 person        128        254       0.81      0.673      0.771      0.542
#                bicycle        128          6      0.492      0.333      0.317      0.251
#                    car        128         46      0.779      0.217      0.279      0.173
#             motorcycle        128          5      0.709        0.8      0.898      0.707
# ...

# %%
# Perform object detection on an image using the model
results = model('https://ultralytics.com/images/bus.jpg')
# Out:
# ...
# 100%|██████████| 476k/476k [00:00<00:00, 4.06MB/s]
# image 1/1 /home/tom-ratsakatika/VSCode/camera-traps/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 7.5ms
# Speed: 2.7ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)

# %%
# Export the model to ONNX format
success = model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.1.40 🚀 Python-3.12.2 torch-2.2.2 CPU (11th Gen Intel Core(TM) i7-11390H 3.40GHz)
#
# PyTorch: starting from 'runs/detect/train8/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# ONNX: starting export with onnx 1.16.0 opset 17...
# ONNX: export success ✅ 0.6s, saved as 'runs/detect/train8/weights/best.onnx' (12.2 MB)
#
# Export complete (2.0s)
# Results saved to /home/tom-ratsakatika/VSCode/camera-traps/runs/detect/train8/weights
# Predict:         yolo predict task=detect model=runs/detect/train8/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train8/weights/best.onnx imgsz=640 data=/home/tom-ratsakatika/miniconda3/envs/camera-traps/lib/python3.12/site-packages/ultralytics/cfg/datasets/coco128.yaml
# Visualize:       https://netron.app

# %%
from pathlib import Path

# Define the path to the 'data' directory
data_dir = Path('data')

# List to hold file paths
image_paths = []

# Loop through all files in 'data' directory and its subdirectories
for file_path in data_dir.rglob('*'):
    # Check if the file is an image (by extension)
    if file_path.suffix.lower() in ['.jpg', '.jpeg', '.png', '.bmp', '.tiff']:
        # Add the image file path to the list
        image_paths.append(str(file_path))

print(image_paths)
# Out:
# ['data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/IMG-20181119-WA0001- Stramtu.jpg', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190204_20190221/Cudde_CC0165/I__00007.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20181228_20190110/Cudde_CC0165/I__00023.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC0165/I__00050.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC0165/I__00052.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC0165/I__00024.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC0165/I__00049.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Anim
# ...

# %%
import subprocess

current_image_path = "data/WildBoarOnly_TrainingSubsample/31BarsaBV/439_I18_Ciuma/20231003_20231110/CC06MO/I_00047b.JPG"

results = model(current_image_path)

# Use subprocess to open the image with Eye of GNOME (eog)
subprocess.run(['eog', current_image_path])
# Out:
# image 1/1 /home/tom-ratsakatika/VSCode/camera-traps/data/WildBoarOnly_TrainingSubsample/31BarsaBV/439_I18_Ciuma/20231003_20231110/CC06MO/I_00047b.JPG: 384x640 1 bear, 8.5ms
# Speed: 3.9ms preprocess, 8.5ms inference, 82.4ms postprocess per image at shape (1, 3, 384, 640)
# eog: symbol lookup error: /snap/core20/current/lib/x86_64-linux-gnu/libpthread.so.0: undefined symbol: __libc_pthread_init, version GLIBC_PRIVATE
# CompletedProcess(args=['eog', 'data/WildBoarOnly_TrainingSubsample/31BarsaBV/439_I18_Ciuma/20231003_20231110/CC06MO/I_00047b.JPG'], returncode=127)
