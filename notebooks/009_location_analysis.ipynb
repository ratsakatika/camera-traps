# %%
import os
import shutil
import pandas as pd
from pathlib import Path
from sklearn.metrics import precision_recall_fscore_support
import numpy as np

# Paths configuration

# PATH_ROOT = "/media/tom-ratsakatika/CRUCIAL 4TB/FCC Camera Trap Data"
PATH_ROOT = "/home/tom-ratsakatika/VSCode/camera-traps/data/"

labelled_data_path = Path(PATH_ROOT + 'structured_data_with_deepfaune.xlsx')

df = pd.read_excel(labelled_data_path, sheet_name='structured_data')

df.head()
# Out:
#    Sort  Session                       Category           GMU TrapSite  \
# 0     9        1  Systematic monitoring of lynx  34SercaitaBV    Ohaba
# 1     9        1  Systematic monitoring of lynx  34SercaitaBV    Ohaba
# 2    10        1  Systematic monitoring of lynx  34SercaitaBV    Ohaba
# 3    11        1  Systematic monitoring of lynx  34SercaitaBV    Ohaba
# 4    11        1  Systematic monitoring of lynx  34SercaitaBV    Ohaba
#
#    Longitude   Latitude  Altitude  StartDate    EndDate  ... score count  \
# 0  25.161698  45.732235       600 2018-02-08 2018-04-09  ...  0.97     1
# 1  25.161698  45.732235       600 2018-02-08 2018-04-09  ...  0.97     1
# 2  25.161698  45.732235       600 2018-02-08 2018-04-09  ...  1.00     0
# 3  25.161698  45.732235       600 2018-02-08 2018-04-09  ...  0.97     0
# 4  25.161698  45.732235       600 2018-02-08 2018-04-09  ...  0.97     1
#
#   humanpresence FCC_Master_Class DF(base)_Master_Class  \
# 0             0              Fox                   Fox
# 1             0              Fox                   Fox
# 2             0          Unknown               Empty**
# 3             0              Fox               Empty**
# 4             0              Fox                   Fox
#
#   DF(sequence)_Master_Class FCC_DF(base)_Match FCC_DF(sequence)_Match  \
# 0                       Fox               True                   True
# 1                       Fox               True                   True
# 2                   Empty**              False                  False
# 3                       Fox              False                   True
# 4                       Fox               True                   True
#
#   DF(base)_DF(sequence)_Match Ground_Truth
# 0                        True          Fox
# 1                        True          Fox
# 2                        True      Unknown
# 3                       False          Fox
# 4                        True          Fox
#
# [5 rows x 57 columns]

# %%
# List of priority species
priority_species = ['Wild boar', 'Wolf', 'Lynx', 'Bear']

# Filter the DataFrame for priority species
filtered_df = df[df['Ground_Truth'].isin(priority_species)]

# Analyze distribution by TrapSite
species_by_trapsite = filtered_df.groupby(['TrapSite', 'Ground_Truth']).size().unstack(fill_value=0)
print("Species distribution by TrapSite:")
print(species_by_trapsite)

# Analyze distribution by Camera ID
species_by_camera = filtered_df.groupby(['Camera ID', 'Ground_Truth']).size().unstack(fill_value=0)
print("\nSpecies distribution by Camera ID:")
print(species_by_camera)

# Analyze distribution by Day/Night
species_by_daynight = filtered_df.groupby(['Day/Night', 'Ground_Truth']).size().unstack(fill_value=0)
print("\nSpecies distribution by Day/Night:")
print(species_by_daynight)

# Analyze distribution by Image Quality
species_by_quality = filtered_df.groupby(['Image quality', 'Ground_Truth']).size().unstack(fill_value=0)
print("\nSpecies distribution by Image Quality:")
print(species_by_quality)
# Out:
# Species distribution by TrapSite:
# Ground_Truth               Bear  Lynx  Wild boar  Wolf
# TrapSite
# 201_ValeaUrsului             47     0          0     0
# 257_Stramba                   6     0          0     0
# 25_ColtulSoimului             5     0          0     0
# 270_PisculCalului            24     3          3    10
# 271_PisculCalului            43     0          7    16
# ...                         ...   ...        ...   ...
# Valea Vladusca_Suchelnita     2    12          2     9
# Valea lui Andreas             1     1          0     0
# Valea marului                 0     0          1     0
# ValeaBughita_Albesti          0    17          0     0
# Vladului                      1     0          0     1
#
# [183 rows x 4 columns]
#
# Species distribution by Camera ID:
# Ground_Truth  Bear  Lynx  Wild boar  Wolf
# Camera ID
# CC013X          68    17         29     4
# CC0140           1     1         10     0
# CC0142          14     4         17     4
# CC0144          10    20         15     9
# CC0146          31     8         23     3
# ...            ...   ...        ...   ...
# CC06X3           1     9          0     0
# CC06X4          23     0         13     1
# CC06X5           1     0          0     0
# CC06X6           1     1          0     0
# CCO152           0     0          2     0
#
# [145 rows x 4 columns]
#
# Species distribution by Day/Night:
# Ground_Truth  Bear  Lynx  Wild boar  Wolf
# Day/Night
# Day           1475   426       1195   253
# Night         1461   721       2098   357
#
# Species distribution by Image Quality:
# Ground_Truth   Bear  Lynx  Wild boar  Wolf
# Image quality
# bad             255   111        391    71
# good           1029   445        931   254
# medium         1521   508       1870   269
# very good       131    83        101    16

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
print(species_by_trapsite)
# Out:
# Ground_Truth                               Bear  Lynx  Wild boar  Wolf
# TrapSite
# 201_ValeaUrsului                             47     0          0     0
# 257_Stramba                                   6     0          0     0
# 25_ColtulSoimului                             5     0          0     0
# 270_PisculCalului                            24     3          3    10
# 271_PisculCalului                            43     0          7    16
# 281_PisculCalului                             7     1          2    10
# 283_PisculCalului                            34     0          0     2
# 287_Comisu                                    2     0         12     1
# 292_Berevoiu Mic                             19     0         50     0
# 293_PisculCalului                            10     2          0     0
# 296_PisculCalului                             6     0          0     0
# Amplast                                       1     2          6     0
# Andrei_Dumitrescu_Comisu_1                   14     0         67     0
# Andrei_Dumitrescu_Comisu_2                   21     0         17     0
# Andrei_Dumitrescu_Comisu_3                   20     0          1     0
# Argesel                                       0     4          0     1
# AsoVanGSTPPapLea - Comanca 2019-2020          3     2         48     5
# AsoVanGSTPPapLea - Runcu 2019-2020            2     0         26     0
# AsoVanGSTPPapLea - Valea marului              2     0         42     0
# AsoVanGTSPPapLea - Plaiul_Marica             13     8         12     0
# AsoVanGTSPPapLea - Rusca 2_Cudde             13     0         17     0
# AsoVanGTSPPapLea - Rusca 2_Cudde_CC0160       6     0          0     0
# AsoVanGTSPPapLea - Rusca_Cudde               10     0         44     1
# AsoVanGTSPPapLea - Rusca_Cudde_CC06MT        19     0         19     0
# AsoVanGTSPPapLea - Steghea 2_Bush_CC00Y10     3     0          0     0
# AsoVanGTSPPapLea - Steghea 2_Bush_CC00Y3      5     0          0     0
# AsoVanGTSPPapLea - Steghea 2_Bush_CC00Y4      0     0         18     0
# AsoVanGTSPPapLea - Steghea 2_Bush_CC00Y5      0     0         18     0
# AsoVanGTSPPapLea - Steghea 2_Bush_CC00Y6      0     0          2     0
# AsoVanGTSPPapLea - Steghea 2_Bush_CC00Y7      0     0         22     0
# AsoVanGTSPPapLea - Steghea 2_Bush_CC00Y9      0     0          2     0
# AsoVanGTSPPapLea - Valea Ursului            140     7        317     9
# AsoVanGTSPPapLea - Valea larga_Cudde        100     0          0     0
# AsoVanGTSPPapLea - Valea ursului jos          2     2         89     0
# AsoVanGTSPPapLea_M_biserici                  12     0          6     0
# AsoVanGTSPPapLea_Magura                       2     1          0     0
# AsoVanGTSPPapLea_Muchia_biserici            309     2        226     4
# Batrana_Calus                                 0     3          4     0
# Batrana_Valea Larga                           0     0          1     0
# Berevoiu_Lutele                              13     4          0    15
# Berivoi                                       3     9          0     0
# Blidaru                                      16     6          1     0
# Bobocului                                     5     0          0     0
# Brusture                                      0     0          0     1
# Bunea                                         0     0          3    11
# Capitanu                                      0    12        116     1
# Carbunaru                                     3     0          9     0
# Cf maguri                                     0     0          6     0
# Ciuma                                        43    39          2    28
# Coja_Lespezi                                  9     3          2     3
# Comisu                                       26     4          6     1
# Crangul Ciorii                                0     2          0     0
# Cretu Sercaita                               97    35         58    15
# Cuca                                          0     0          1     0
# Culmea Berivoiu                               4     1          0     0
# Culmea Glimeea - Muntele Paur                15    15         11     1
# Culmea Gruiet                                 1     1          0     4
# Culmea Magurii                                0     2          0     0
# Culmea uliului                                1    36          3     0
# Dealu Mic                                     0     1          6     1
# Dealul Mic                                    1     2          3     0
# Dosul Magurii                                 7     0         11     0
# Dosul Pietrei                                 6    41          0     4
# Dosul Pietrii                                 0     5          7     2
# Dracsin                                      46     3         23     0
# Draganu                                      71    29         35     6
# Draxin                                        9    12         10    11
# Extra_Laviniu_Muntele Steghea                14     0         62     0
# Faget                                        20    51         67    19
# Fantanea                                      0     3          0     0
# Fata Iliei                                    9     3          3    14
# Fata Rea                                     36     0          0     0
# Fundu draganului                              0    12          1     2
# Gaina                                         7     6         40     3
# Gaozea                                        4     4          5     1
# Garofita_Tamasel                             14     5          0     2
# Geabelea                                     30     0          0     5
# Glimea Blondana                              16     0          5     0
# Glimeiei                                      1     0          0     0
# Griul Ratei                                   0     0         14     0
# Groape-piatra galbena                        10     2          1     0
# Grui                                        164    10         48    29
# Gruiul Lung                                   5     7          2     0
# Gruiul Ratei                                  8     0          0     0
# Gruiul lung                                   2     2         19     3
# Hotarului_Paraul larg                        13     4          0     7
# Huluba                                        2     3         15     0
# Iaru                                          0     0          3     0
# Ivan Valley                                   0     0          0     2
# Lalu                                          0     4          1     4
# M Draganu                                     0     0          6     0
# Magura                                      265     1        257     0
# Magura Mateias                                0     0        130     0
# Mara Mica                                     1     0          0     0
# Mara mare                                   144     1          0     0
# Marginea Domneasca                            0     0          2    15
# Marginea Domneasca_Gaina                      0     1          0     0
# Mucea porcului                                0     3          0     0
# Mulia Tagla                                  11     2          0     0
# Muntele Bobocului                             7     3          0     1
# Muntele Calugarul                             2     0         23     1
# Muntele Capitanu                              2     0         10     1
# Muntele Plaghia                               5     0          6     2
# Muntele Prislopului                           0     0          1     2
# Muntele Vartoapelor                           0     0          2     0
# Muntele lui Ivan - Piscul Plaiului            0     2          9    10
# Nemaia                                        4     4          0     0
# Ohaba                                        56     4         57     2
# Olaneasca                                     1     0          0     0
# Orlovschi                                     1     0          3     2
# Otetelea                                      0     3          0     0
# PNPC_Dealul Sasului                           0    17          0     0
# PNPC_Sirnea                                   0     0          8     0
# Paraul cu Apa                                 3     0          0     0
# Paraul_Manastirii                            30   374          0     0
# Piatra                                       11     0         19     8
# Piatra Berbecilor                             0     1          0     6
# Pietricica                                    1     0          2     1
# Piscul Carlanului                             1     0          0     0
# Piscul Soimului                               0    46         11    44
# Piscul Turcilor                               6     0         20     1
# Piscul richitei                               1    11          0     5
# Pleasa Cetateni                               5     0          1     0
# Pleasa Popii                                  3     0          0     0
# Podul Otic                                    5     0          0     0
# Poduri                                        0    11          0     0
# Post Laviniu Plaiul Marica                    6     2          8     0
# Post Laviniu Rusca                           27     0         38     1
# Post Laviniu Valea Larga                     61     0          0     0
# Post Laviniu Valea Ursului                   51     4        105     8
# Preajba                                       3     7          1     0
# Priseaca                                     47     0          5     2
# Richita                                      16     2         13     0
# Saivanele Rosu_Algai                          0     0          2     0
# Sofinac                                      11     0          2     6
# Stana Pietricica_Cuibul Uliului               7     6          5     8
# Steghia                                       6     8          2     0
# Stramba                                     126    25         20     8
# Stramba Tagla                                24     2         23     1
# Stramba ridge                                59    11        112    21
# Stramba_Tagla                                 4     2          0     0
# Strambisoara                                 10    10         16     2
# Strimba ridge                                 0     3          3     5
# Suchelnita                                    0     9          0     5
# Tagla                                         0     2          0     0
# Talfa                                         0     1          0     2
# Tamas                                         1     1          8     4
# Tamasului                                     0     4          0     0
# Tancava                                       6     0         33     5
# Tefeleica                                     1     4         11     2
# Teleni                                       13     1          5     2
# Terciu                                        0     3          6     0
# Tiganca                                      13    10          0     0
# Tilisoare                                    17     0        306     1
# Tincava                                       0     0          0    33
# Uliului                                       0     1         13     0
# Ursului                                       0     1          3     0
# V Ivan                                        6     4          0     0
# Vacaria Mare                                  2     2          0     0
# Vaja                                          0     0          0     2
# Valea Carstii                                 0     2         56     0
# Valea Fiasului                                8     4         19     2
# Valea Foisorului                              3     0          0     0
# Valea Frasinului                             16     1         77     6
# Valea Gruiului                               29    25         27    73
# Valea Hotarului                               1     0          0     0
# Valea Larga                                   2     7          2     0
# Valea Larga_Calus                             0     6          2     0
# Valea Mare                                   52    30         82     5
# Valea Otic                                   11     4          2    11
# Valea Rea                                    15     3          2     5
# Valea Runcului                               42     0          1     0
# Valea Runcului_Priseaca                       0     0         16     5
# Valea Seaca                                   0     2          4     2
# Valea Ursului                                 0     0          4     0
# Valea Ursului_Lalu                            0     2          9     1
# Valea Vaja                                    3     2          3     9
# Valea Vladului                               37     5          0     8
# Valea Vladusca_Suchelnita                     2    12          2     9
# Valea lui Andreas                             1     1          0     0
# Valea marului                                 0     0          1     0
# ValeaBughita_Albesti                          0    17          0     0
# Vladului                                      1     0          0     1

# %%
df['Date'] = pd.to_datetime(df['Date'])

# Define a function to determine the season based on month
def get_season(date):
    month = date.month
    if month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Autumn'
    else:
        return 'Winter'

# Apply the function to create a new 'Season' column
df['Season'] = df['Date'].apply(get_season)

# List of priority species
priority_species = ['Wild boar', 'Wolf', 'Lynx', 'Bear']

# Filter the DataFrame for priority species
filtered_df = df[df['Ground_Truth'].isin(priority_species)]

# Analyze distribution by Season
species_by_season = filtered_df.groupby(['Season', 'Ground_Truth']).size().unstack(fill_value=0)
print("Species occurrences by Season:")
print(species_by_season)


# Calculate total images per season
total_images_per_season = df.groupby('Season').size()

# Calculate the proportion of each species occurrences as a percentage of total images taken in these seasons
species_proportion_by_season = (species_by_season.div(total_images_per_season, axis=0) * 100).fillna(0)

print("\nSpecies occurrences as a percentage of total images by Season:")
print(species_proportion_by_season.round(2))
# Out:
# Species occurrences by Season:
# Ground_Truth  Bear  Lynx  Wild boar  Wolf
# Season
# Autumn        1280   117       1056   112
# Spring         992   598        927   172
# Summer         427     5        437    30
# Winter         237   427        873   296
#
# Species occurrences as a percentage of total images by Season:
# Ground_Truth   Bear   Lynx  Wild boar  Wolf
# Season
# Autumn        19.43   1.78      16.03  1.70
# Spring        17.42  10.50      16.27  3.02
# Summer        22.65   0.27      23.18  1.59
# Winter         4.37   7.87      16.09  5.45

# %%
import matplotlib.pyplot as plt

animal = "Wild boar"

# Calculate total captures per TrapSite
total_captures = df.groupby('TrapSite').size()

# Filter the DataFrame for Wild boar only and calculate captures per TrapSite
wild_boar_captures = df[df['Ground_Truth'] == animal].groupby('TrapSite').size()

# Calculate the proportion of Wild boar captures
boar_proportion = (wild_boar_captures / total_captures) * 100

# Filter for proportions greater than 0%
high_boar_proportion = boar_proportion[boar_proportion > 0]

# Sort the proportions for better visualization
high_boar_proportion = high_boar_proportion.sort_values(ascending=False)

# Get corresponding counts of Wild boar for the filtered sites
filtered_wild_boar_captures = wild_boar_captures[high_boar_proportion.index]

# Plotting
plt.figure(figsize=(20, 5))
high_boar_proportion.plot(kind='bar', color='brown')
plt.title(f'{animal} captures by trap site, as a proportion of all captures at that site')
plt.xlabel('TrapSite')
plt.ylabel('Percentage of Total Captures')
plt.xticks(rotation=90, fontsize=8)

# Annotate bars with the absolute number of captures
for idx, value in enumerate(high_boar_proportion):
    plt.text(idx, value + 1, f'{filtered_wild_boar_captures[idx]:.0f}', ha='center', va='bottom', fontsize=8, rotation=90)

plt.show()
# Out:
# /tmp/ipykernel_5082/432140505.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(idx, value + 1, f'{filtered_wild_boar_captures[idx]:.0f}', ha='center', va='bottom', fontsize=8, rotation=90)

# %%
import matplotlib.pyplot as plt

animal = "Wild boar"

# Calculate total captures per TrapSite
total_captures = df.groupby('TrapSite').size()

# Filter the DataFrame for Wild boar only and calculate captures per TrapSite
wild_boar_captures = df[df['Ground_Truth'] == animal].groupby('TrapSite').size()

# Calculate total Wild boar captures across all TrapSites
total_wild_boar_captures = wild_boar_captures.sum()

# Calculate the proportion of Wild boar captures as a percentage of total Wild boar captures
boar_proportion = (wild_boar_captures / total_wild_boar_captures) * 100

# Filter for proportions greater than 0%
high_boar_proportion = boar_proportion[boar_proportion > 0]

# Sort the proportions for better visualization
high_boar_proportion = high_boar_proportion.sort_values(ascending=False)

# Get corresponding counts of Wild boar for the filtered sites
filtered_wild_boar_captures = wild_boar_captures[high_boar_proportion.index]

# Plotting
plt.figure(figsize=(20, 5))
high_boar_proportion.plot(kind='bar', color='brown')
plt.title(f'{animal} captures by trap site, as a proportion of all {animal} captures')
plt.xlabel('TrapSite')
plt.ylabel('Percentage of Total Wild Boar Captures')
plt.xticks(rotation=90, fontsize=8)

# Annotate bars with the absolute number of captures
for idx, value in enumerate(high_boar_proportion):
    plt.text(idx, value + 1, f'{filtered_wild_boar_captures[idx]:.0f}', ha='center', va='bottom', fontsize=8, rotation=90)

plt.show()
# Out:
# /tmp/ipykernel_5082/3572750781.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(idx, value + 1, f'{filtered_wild_boar_captures[idx]:.0f}', ha='center', va='bottom', fontsize=8, rotation=90)

# %%
df.columns
# Out:
# Index(['Sort', 'Session', 'Category', 'GMU', 'TrapSite', 'Longitude',
#        'Latitude', 'Altitude', 'StartDate', 'EndDate', 'TrapCode', 'Camera',
#        'Type', 'Date', 'Time', 'RawName', 'Species', 'NoAnimals', 'Sex',
#        'Image quality', 'Problem', 'Sequence', 'Comments', 'Formatted Date',
#        'Formatted Time', 'MatchID', 'File ID', 'Original Path',
#        'Original Filename', 'File Extension', 'Original Date', 'Original Time',
#        'Camera Brand', 'Color Space', 'Flash Used', 'Flash Info', 'Day/Night',
#        'Camera ID', 'Sunrise', 'Sunset', 'Full File Name', 'date', 'seqnum',
#        'seqcount', 'predictionbase', 'scorebase', 'prediction', 'score',
#        'count', 'humanpresence', 'FCC_Master_Class', 'DF(base)_Master_Class',
#        'DF(sequence)_Master_Class', 'FCC_DF(base)_Match',
#        'FCC_DF(sequence)_Match', 'DF(base)_DF(sequence)_Match', 'Ground_Truth',
#        'Season'],
#       dtype='object')
