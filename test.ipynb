# %%
from ultralytics import settings

# View all settings
print(settings)
# Out:
# {'settings_version': '0.0.4', 'datasets_dir': '/home/tom-ratsakatika/VSCode/camera-traps/datasets', 'weights_dir': 'weights', 'runs_dir': 'runs', 'uuid': 'caac3e504e111a4659f6a3dd5f3bbf05e178441fff904e37cc355434eebd143d', 'sync': True, 'api_key': '', 'openai_api_key': '', 'clearml': True, 'comet': True, 'dvc': True, 'hub': True, 'mlflow': True, 'neptune': True, 'raytune': True, 'tensorboard': True, 'wandb': True}

# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
model = YOLO('yolov8n.yaml')

# %%
# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8n.pt')

# %%
# Train the model using the 'coco128.yaml' dataset for 3 epochs
results = model.train(data='coco128.yaml', epochs=3)
# Out:
# /home/tom-ratsakatika/miniconda3/envs/camera-traps/lib/python3.12/site-packages/torch/cuda/__init__.py:141: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403463728/work/c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Ultralytics YOLOv8.1.40 🚀 Python-3.12.2 torch-2.2.2 CPU (11th Gen Intel Core(TM) i7-11390H 3.40GHz)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=coco128.yaml, epochs=3, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train7, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    897664  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# Model summary: 225 layers, 3157200 parameters, 3157184 gradients
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /home/tom-ratsakatika/VSCode/camera-traps/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100%|██████████| 128/128 [00:00<?, ?it/s]
# val: Scanning /home/tom-ratsakatika/VSCode/camera-traps/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100%|██████████| 128/128 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train7/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train7
# Starting training for 3 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# Evaluate the model's performance on the validation set
results = model.val()
# Out:
# /home/tom-ratsakatika/miniconda3/envs/camera-traps/lib/python3.12/site-packages/torch/cuda/__init__.py:141: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403463728/work/c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Ultralytics YOLOv8.1.40 🚀 Python-3.12.2 torch-2.2.2 CPU (11th Gen Intel Core(TM) i7-11390H 3.40GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# Dataset 'coco.yaml' images not found ⚠️, missing path '/home/tom-ratsakatika/VSCode/camera-traps/datasets/coco/val2017.txt'
# Downloading https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017labels-segments.zip to '/home/tom-ratsakatika/VSCode/camera-traps/datasets/coco2017labels-segments.zip'...
#  98%|█████████▊| 166M/169M [00:45<00:00, 3.83MB/s]
# Downloading http://images.cocodataset.org/zips/train2017.zip to '/home/tom-ratsakatika/VSCode/camera-traps/datasets/coco/images/train2017.zip'...
# Downloading http://images.cocodataset.org/zips/test2017.zip to '/home/tom-ratsakatika/VSCode/camera-traps/datasets/coco/images/test2017.zip'...
# Downloading http://images.cocodataset.org/zips/val2017.zip to '/home/tom-ratsakatika/VSCode/camera-traps/datasets/coco/images/val2017.zip'...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Evaluate the model's performance on the validation set
# ----> 2 results = model.val()
#
# File ~/miniconda3/envs/camera-traps/lib/python3.12/site-packages/ultralytics/engine/model.py:526, in Model.val(self, validator, **kwargs)
#     523 args = {**self.overrides, **custom, **kwargs, "mode": "val"}  # highest priority args on the right
#     525 validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 526 validator(model=self.model)
#     527 self.metrics = validator.metrics
#     528 return validator.metrics
#
# File ~/miniconda3/envs/camera-traps/lib/python3.12/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/camera-traps/lib/python3.12/site-packages/ultralytics/engine/validator.py:143, in BaseValidator.__call__(self, trainer, model)
#     140     LOGGER.info(f"Forcing batch=1 square inference (1,3,{imgsz},{imgsz}) for non-PyTorch models")
#     142 if str(self.args.data).split(".")[-1] in {"yaml", "yml"}:
# --> 143     self.data = check_det_dataset(self.args.data)
#     144 elif self.args.task == "classify":
#     145     self.data = check_cls_dataset(self.args.data, split=self.args.split)
#
# File ~/miniconda3/envs/camera-traps/lib/python3.12/site-packages/ultralytics/data/utils.py:338, in check_det_dataset(dataset, autodownload)
#     336     r = os.system(s)
#     337 else:  # python script
# --> 338     exec(s, {"yaml": data})
#     339 dt = f"({round(time.time() - t, 1)}s)"
#     340 s = f"success ✅ {dt}, saved to {colorstr('bold', DATASETS_DIR)}" if r in {0, None} else f"failure {dt} ❌"
#
# File <string>:14
#
# File ~/miniconda3/envs/camera-traps/lib/python3.12/site-packages/ultralytics/utils/downloads.py:483, in download(url, dir, unzip, delete, curl, threads, retry, exist_ok)
#     481 if threads > 1:
#     482     with ThreadPool(threads) as pool:
# --> 483         pool.map(
#     484             lambda x: safe_download(
#     485                 url=x[0],
#     486                 dir=x[1],
#     487                 unzip=unzip,
#     488                 delete=delete,
#     489                 curl=curl,
#     490                 retry=retry,
#     491                 exist_ok=exist_ok,
#     492                 progress=threads <= 1,
#     493             ),
#     494             zip(url, repeat(dir)),
#     495         )
#     496         pool.close()
#     497         pool.join()
#
# File ~/miniconda3/envs/camera-traps/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/miniconda3/envs/camera-traps/lib/python3.12/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/miniconda3/envs/camera-traps/lib/python3.12/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/miniconda3/envs/camera-traps/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/miniconda3/envs/camera-traps/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
# Perform object detection on an image using the model
results = model('https://ultralytics.com/images/bus.jpg')
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /home/tom-ratsakatika/VSCode/camera-traps/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 88.6ms
# Speed: 1.8ms preprocess, 88.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)

# %%
# Export the model to ONNX format
success = model.export(format='onnx')

# %%
from pathlib import Path

# Define the path to the 'data' directory
data_dir = Path('data')

# List to hold file paths
image_paths = []

# Loop through all files in 'data' directory and its subdirectories
for file_path in data_dir.rglob('*'):
    # Check if the file is an image (by extension)
    if file_path.suffix.lower() in ['.jpg', '.jpeg', '.png', '.bmp', '.tiff']:
        # Add the image file path to the list
        image_paths.append(str(file_path))

# Now, image_paths contains all the image file paths
print(image_paths)
# Out:
# ['data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/IMG-20181119-WA0001- Stramtu.jpg', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190204_20190221/Cudde_CC0165/I__00007.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20181228_20190110/Cudde_CC0165/I__00023.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC0165/I__00050.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC0165/I__00052.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC0165/I__00024.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC0165/I__00049.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC0165/I__00053.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC0165/I__00023.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC0165/I_00051b.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC0165/I__00054.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC0165/I_00051a.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC06M5/I__00009.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC06M5/I__00008.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC06M5/I__00010.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC06M5/I_00007b.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC06M5/I_00007a.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC06M5/I__00019.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC06M5/I__00022.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC06M5/I__00023.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC06M5/I__00006.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC06M5/I__00018.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20190318_20190403/Cudde_CC06M5/I__00021.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20181212_20181228/Cudde_CC0165/I__00077.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20181212_20181228/Cudde_CC0165/I__00075.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/128_208_Tiganca/20181212_20181228/Cudde_CC0165/I__00076.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/131_192_Batrana_Valea Larga/20190315_20190403/Cudde_CC06U1/I__00007.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/131_192_Batrana_Valea Larga/20190315_20190403/Cudde_CC06U1/I__00011.JPG', 'data/AnimalsOnly_TrainingSubsample/Season 2 - Animals only/18RaulTarguluiAG/131_192_Batrana_Valea Larga/20190 ...

# %%
import subprocess

current_image_path = image_paths[1000]

results = model(image_paths)

# Use subprocess to open the image with Eye of GNOME (eog)
subprocess.run(['eog', current_image_path])
